# %% [markdown]
# <a href="https://colab.research.google.com/github/connectasp/NLP_Task8/blob/main/NLP_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **You need to translate each word or sentence from English to Spanish, French and German**

# %%
pip install itranslate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 KB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 KB 6.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from itranslate import itranslate

# %%
Lang_Trans = pd.read_csv("English.csv")
Lang_Trans.head()
# Out:
#   English words/sentences
# 0                     Hi.
# 1                    Run!
# 2                    Run!
# 3                    Who?
# 4                    Wow!

# %%
Lang_Trans.shape
# Out:
# (175621, 1)

# %%
Lang_Trans.duplicated().sum()
# Out:
# 52521

# %%
Lang_Trans = Lang_Trans.drop_duplicates(keep='first',ignore_index=True)

# %%
Lang_Trans.shape
# Out:
# (123100, 1)

# %%
Translations = Lang_Trans[:500]
Translations["Spanish"] = Translations["English words/sentences"].apply(lambda x : itranslate(x, to_lang = 'es'))
Translations
# Out:
# <ipython-input-11-35a48e440ad4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Translations["Spanish"] = Translations["English words/sentences"].apply(lambda x : itranslate(x, to_lang = 'es'))
#     English words/sentences      Spanish
# 0                       Hi.        Hola.
# 1                      Run!     ¡Correr!
# 2                      Who?      ¿Quién?
# 3                      Wow!       ¡Guau!
# 4                     Fire!      ¡Fuego!
# ..                      ...          ...
# 495              Stop that!       ¡Para!
# 496              Stop that.        Para.
# 497              Stop them.  Detenerlos.
# 498              Take care!   ¡Cuidarse!
# 499              Take care.    Cuidarse.
#
# [500 rows x 2 columns]

# %%
Translations["French"] = Translations["English words/sentences"].apply(lambda x : itranslate(x, to_lang = 'fr'))
Translations
# Out:
# <ipython-input-12-bfb2c666366e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Translations["French"] = Translations["English words/sentences"].apply(lambda x : itranslate(x, to_lang = 'fr'))
#     English words/sentences      Spanish                French
# 0                       Hi.        Hola.                Salut.
# 1                      Run!     ¡Correr!                Cours!
# 2                      Who?      ¿Quién?                  Qui?
# 3                      Wow!       ¡Guau!                 Ouah!
# 4                     Fire!      ¡Fuego!                  Feu!
# ..                      ...          ...                   ...
# 495              Stop that!       ¡Para!            Arrête ça!
# ...

# %%
Translations["German"] = Translations["English words/sentences"].apply(lambda x : itranslate(x, to_lang = 'de'))
Translations
# Out:
# <ipython-input-13-d7ce0bfafacd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Translations["German"] = Translations["English words/sentences"].apply(lambda x : itranslate(x, to_lang = 'de'))
#     English words/sentences      Spanish                French  \
# 0                       Hi.        Hola.                Salut.
# 1                      Run!     ¡Correr!                Cours!
# 2                      Who?      ¿Quién?                  Qui?
# 3                      Wow!       ¡Guau!                 Ouah!
# 4                     Fire!      ¡Fuego!                  Feu!
# ..                      ...          ...                   ...
# 495              Stop that!       ¡Para!            Arrête ça!
# ...
