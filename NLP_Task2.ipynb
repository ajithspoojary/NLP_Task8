# %% [markdown]
# <a href="https://colab.research.google.com/github/connectasp/NLP_Task8/blob/main/NLP_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a program that needs to automatically correct that spelling from the word or a given sentence. (Language : English)
# Note:  show 100 data point outputs both in words and sentence.

# %%
pip install autocorrect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 KB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622381 sha256=6d08b234a7b81cfff7382648c5cddc48feb494f2c618b84808850efff7e051c7
#   Stored in directory: /root/.cache/pip/wheels/72/b8/3b/a90246d13090e85394a8a44b78c8abf577c0766f29d6543c75
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
import nltk
from autocorrect import Speller
import pandas as pd

# %%
wrong_spell = pd.read_fwf("misspelled-words.txt")
wrong_spell
# Out:
#     wrong_spelled_words
# 0               absense
# 1            acceptible
# 2           accidentaly
# 3            accidently
# 4            accomodate
# ..                  ...
# 376               wierd
# 377             wilfull
# 378             withold
# 379            writeing
# 380            writting
#
# [381 rows x 1 columns]

# %%
words = wrong_spell[:100]
words.shape
# Out:
# (100, 1)

# %%
words.duplicated().sum()
# Out:
# 0

# %%
words.head(20)
# Out:
#    wrong_spelled_words
# 0              absense
# 1           acceptible
# 2          accidentaly
# 3           accidently
# 4           accomodate
# 5            accordian
# 6              acerage
# 7              acheive
# 8           acknowlege
# 9           acommodate
# 10        acquaintence
# 11              acrage
# 12             adquire
# 13           adrenalin
# 14              adress
# 15            adultary
# 16          adviseable
# 17           advizable
# 18           aggresion
# 19           agression

# %%
spell_corrector = Speller(lang ="en")
words["corrected_words"] = words["wrong_spelled_words"].apply(lambda x : spell_corrector(x))
words
# Out:
# <ipython-input-11-b39ca9ce7410>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   words["corrected_words"] = words["wrong_spelled_words"].apply(lambda x : spell_corrector(x))
#    wrong_spelled_words corrected_words
# 0              absense         absence
# 1           acceptible      acceptable
# 2          accidentaly    accidentally
# 3           accidently        accident
# 4           accomodate     accommodate
# ..                 ...             ...
# 95            concious       conscious
# 96         confortable     comfortable
# 97        congradulate    congratulate
# 98       consciencious   conscientious
# 99            consious       conscious
#
# [100 rows x 2 columns]

# %% [markdown]
# **Sentences**

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from autocorrect import Speller

# %%
sentence = pd.read_fwf("misspelled-sentence.txt")
sentence = sentence.drop(['Unnamed: 1','Unnamed: 2'],axis=1)
sentence.head()
# Out:
#        Wrong-Sentences
# 0   I really appreciat
# 1           I am sory.
# 2  How does tat sound?
# 3    That sounds grat.
# 4         neverr mind.

# %%
sentence.duplicated().sum()
# Out:
# 0

# %%
spell_corrector = Speller(lang ="en")
sentence["corrected_sentence"] = sentence["Wrong-Sentences"].apply(lambda x : spell_corrector(x))
sentence
# Out:
#                   Wrong-Sentences             corrected_sentence
# 0              I really appreciat            I really appreciate
# 1                      I am sory.                    I am story.
# 2             How does tat sound?            How does tat sound?
# 3               That sounds grat.             That sounds great.
# 4                    neverr mind.                    never mind.
# ..                            ...                            ...
# 95    The job is practicaly done.     The job is practical done.
# 96    The kids are finaly asleep.     The kids are final asleep.
# 97  The lid screws onto the jaar.  The lid screws onto the jaar.
# 98    The light sudenly went out.   The light suddenly went out.
# 99    The machin is out of order.   The machine is out of order.
#
# [100 rows x 2 columns]
